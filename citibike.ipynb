# %%
import os
import pandas as pd
import glob


files = glob.glob('data/*.csv')
files
# Out:
# ['data\\JC-201509-citibike-tripdata.csv',
#  'data\\JC-201510-citibike-tripdata.csv',
#  'data\\JC-201511-citibike-tripdata.csv',
#  'data\\JC-201512-citibike-tripdata.csv',
#  'data\\JC-201604-citibike-tripdata.csv',
#  'data\\JC-201605-citibike-tripdata.csv',
#  'data\\JC-201606-citibike-tripdata.csv',
#  'data\\JC-201607-citibike-tripdata.csv',
#  'data\\JC-201608-citibike-tripdata.csv',
#  'data\\JC-201609-citibike-tripdata.csv',
#  'data\\JC-20161-citibike-tripdata.csv',
#  'data\\JC-201610-citibike-tripdata.csv',
#  'data\\JC-20162-citibike-tripdata.csv',
#  'data\\JC-20163-citibike-tripdata.csv']

# %%
df = pd.concat([pd.read_csv(f) for f in glob.glob('data/*.csv')], ignore_index = True)

# %%
df.head()
# Out:
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0             61  2015-09-21 14:53:16  2015-09-21 14:54:17              3185
# 1            290  2015-09-21 14:55:59  2015-09-21 15:00:50              3183
# 2            786  2015-09-21 14:56:14  2015-09-21 15:09:21              3183
# 3            477  2015-09-21 14:58:35  2015-09-21 15:06:32              3203
# 4            451  2015-09-21 14:59:55  2015-09-21 15:07:27              3203
#
#   Start Station Name  Start Station Latitude  Start Station Longitude  \
# 0          City Hall               40.717733               -74.043845
# 1     Exchange Place               40.716247               -74.033459
# 2     Exchange Place               40.716247               -74.033459
# 3      Hamilton Park               40.727596               -74.044247
# 4      Hamilton Park               40.727596               -74.044247
#
#    End Station ID End Station Name  End Station Latitude  \
# ...

# %%
# rename values in gender column
df['Gender'] = df['Gender'].map({1:'male', 0:'unknown', 2:'female'})

# %%
# add a minutes column
df['Trip Duration (min)'] = df['Trip Duration']/60

# %%
# df['time'] = df['Start Time'][:1]
# df['time'] = df['Start Time'].astype(str)
# df['time'] = df.time.str[10:]

# %%
df.head()
# Out:
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0             61  2015-09-21 14:53:16  2015-09-21 14:54:17              3185
# 1            290  2015-09-21 14:55:59  2015-09-21 15:00:50              3183
# 2            786  2015-09-21 14:56:14  2015-09-21 15:09:21              3183
# 3            477  2015-09-21 14:58:35  2015-09-21 15:06:32              3203
# 4            451  2015-09-21 14:59:55  2015-09-21 15:07:27              3203
#
#   Start Station Name  Start Station Latitude  Start Station Longitude  \
# 0          City Hall               40.717733               -74.043845
# 1     Exchange Place               40.716247               -74.033459
# 2     Exchange Place               40.716247               -74.033459
# 3      Hamilton Park               40.727596               -74.044247
# 4      Hamilton Park               40.727596               -74.044247
#
#    End Station ID End Station Name  End Station Latitude  \
# ...

# %%
# df.to_csv("CB201516.csv", sep='\t')
